# %%
import matplotlib.pyplot as plt
from obspy.clients.fdsn import Client
import obspy

import torch
from chronos import ChronosPipeline
import numpy as np

import matplotlib.pyplot as plt

from gluonts.dataset.split import split
from einops import rearrange
from uni2ts.eval_util.data import get_gluonts_test_dataset
from uni2ts.eval_util.plot import plot_single, plot_next_multi
from uni2ts.model.moirai import MoiraiForecast, MoiraiModule
from gluonts.dataset.pandas import PandasDataset
# Out:
# /Users/marinedenolle/GitHub/quakeLLM/src/uni2ts/src/uni2ts/common/env.py:43: UserWarning: Failed to load .env file.
#   warnings.warn("Failed to load .env file.")

# %%
n_samples = 100 # number of samples to generate and then take the median on
prediction_time = 15 # seconds
context_time = 20 # seconds

# %% [markdown]
# ## Get data
# an earthquake waveform from ridgecrest

# %%
# some metadata

df = 5

# %%
# Create a client to connect to the SCEDC data center
client = Client("SCEDC")

# download a SCEDC earthquake catalog using obspy
starttime = obspy.UTCDateTime("2016-01-01")
endtime = obspy.UTCDateTime("2020-01-01")
minlatitude = 32.0
minlongitude = -125.0
maxlatitude = 42.0
maxlongitude = -114.0
minmagnitude = 6
quake_catalog = client.get_events(starttime=starttime,\
             endtime=endtime, minlatitude=minlatitude, \
                minlongitude=minlongitude, maxlatitude=maxlatitude, \
                    maxlongitude=maxlongitude, minmagnitude=minmagnitude)
print(quake_catalog)
# Out:
# 2 Event(s) in Catalog:
# 2019-07-06T03:19:53.040000Z | +35.770, -117.599 | 7.1  Mw | manual
# 2019-07-04T17:33:49.000000Z | +35.705, -117.504 | 6.4  Mw | manual

# %%
# get a seismogram from CI.RPV..BHZ for the large earthquake in the first element of quake_catalog
event = quake_catalog[0]
origin = event.origins[0]
# convert the origin time to a UTCDateTime object
event_time = obspy.UTCDateTime(origin.time)
z=client.get_waveforms("CI", "RPV", "", "BH*", event_time, event_time + 60*10)
# downsample to df Hz

z.resample(df)
data = np.zeros(shape=(3, len(z[0].data)))
data[0] = z[0].data
data[1] = z[1].data
data[2] = z[2].data

# %%
# now we are going to reshape the data into a format that can be used by the ChronosPipeline
# data = np.expand_dims(data, axis=0)
predict_time = prediction_time; #in sec
# n_predict will be the minimum between int(predict_time*df) and 64
n_predict = min([int(predict_time*df),64]) # index, should be less than 64 for Chronos
# n_predict = min([int(predict_time*df),64]) # index, should be less than 64 for Chronos
predict_time = n_predict/df # in sec
start_time = 40; # start in sec
nstart = int(start_time*df) # in sec
end_time = start_time+context_time; # insec
nend = int(end_time*df) # index

#create a time vector with sampling rate df
ndata_and_predict = int((predict_time+end_time-start_time)*df)
time = np.linspace(start_time, end_time+predict_time,ndata_and_predict)

fig,ax=plt.subplots(nrows=3,ncols=1)
for i in range(0,data.shape[0]):
    ax[i].plot(time,data[i,nstart:nend+n_predict],'r')
    ax[i].plot(time[:-n_predict],data[i,nstart:nend],'k')
    ax[i].set_ylabel('Amplitude')
    ax[i].set_xlabel('Time (s)')
    ax[i].set_xlim([start_time,end_time+predict_time])
    ax[i].grid();

# %% [markdown]
# ## Chronos
#
# Context is maximum 512 points
# Prediction is maximum 64 points.
#
# Whatch out thta MOIRAI can handle longer foreast.

# %%
chronos_pipeline = ChronosPipeline.from_pretrained(
    "amazon/chronos-t5-base",
    device_map="cpu",  # use "cpu" for CPU inference and "mps" for Apple Silicon
    torch_dtype=torch.bfloat16,
)

# %% [markdown]
# ## MOIRAI
#
# ### Settings
# SIZE: model size, select the model size of Moirai to perform inference with
#
# CTX: context length, how many time steps the model will take as input for inference
#
# PSZ: patch size, how many time steps to perform patching with
#
# BSZ: batch size, number of samples in each batch for inference

# %%
SIZE = "small"  # model size: choose from {'small', 'base', 'large'}
CTX = 368  # context length: any positive integer
PRED = n_predict  # prediction length: any positive integer
PSZ = "auto"  # patch size: choose from {"auto", 8, 16, 32, 64, 128}
BSZ = 32  # batch size: any positive integer

# %%
PRED
# Out:
# 64

# %%
# Prepare model
moirai_model = MoiraiForecast(
    module=MoiraiModule.from_pretrained(f"Salesforce/moirai-1.0-R-small"),
    prediction_length=PRED,
    context_length=CTX,
    patch_size=PSZ,
    num_samples=n_samples,
    target_dim=1,
    feat_dynamic_real_dim=0,
    past_feat_dynamic_real_dim=0,
)

# %% [markdown]
# ### Moment

# %%
from momentfm import MOMENTPipeline

moment_model = MOMENTPipeline.from_pretrained(
    "AutonLab/MOMENT-1-large", 
    model_kwargs={
        'task_name': 'forecasting',
        'forecast_horizon': prediction_time,
        'head_dropout': 0.1,
        'weight_decay': 0,
        'freeze_encoder': True, # Freeze the patch embedding layer
        'freeze_embedder': True, # Freeze the transformer encoder
        'freeze_head': False, # The linear forecasting head must be trained
    },
    # local_files_only=True,  # Whether or not to only look at local files (i.e., do not try to download the model).
)

# %% [markdown]
# ## Zero-shot prediction
#
# ### Chronos

# %%
# Chronos just takes a densor of data
# context must be either a 1D tensor, a list of 1D tensors,
# or a left-padded 2D tensor with batch as the first dimension
# forecast shape: [num_series, num_samples, prediction_length]
chronos_forecast = chronos_pipeline.predict(
    context=torch.tensor(data[:,nstart:nend], dtype=torch.float32),
    prediction_length=n_predict,
    num_samples=n_samples,
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 5
#       1 # Chronos just takes a densor of data
#       2 # context must be either a 1D tensor, a list of 1D tensors,
#       3 # or a left-padded 2D tensor with batch as the first dimension
#       4 # forecast shape: [num_series, num_samples, prediction_length]
# ----> 5 chronos_forecast = chronos_pipeline.predict(
#       6     context=torch.tensor(data[:,nstart:nend], dtype=torch.float32),
#       7     prediction_length=n_predict,
#       8     num_samples=n_samples,
#       9 )
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/chronos/chronos.py:512, in ChronosPipeline.predict(self, context, prediction_length, num_samples, temperature, top_k, top_p, limit_prediction_length)
#     508 while remaining > 0:
#     509     token_ids, attention_mask, scale = self.tokenizer.context_input_transform(
#     510         context_tensor
#     511     )
# --> 512     samples = self.model(
#     513         token_ids.to(self.model.device),
#     514         attention_mask.to(self.model.device),
#     515         min(remaining, self.model.config.prediction_length),
#     516         num_samples,
#     517         temperature,
#     518         top_k,
#     519         top_p,
#     520     )
#     521     prediction = self.tokenizer.output_transform(
#     522         samples.to(scale.device), scale
#     523     )
#     525     predictions.append(prediction)
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/chronos/chronos.py:336, in ChronosModel.forward(self, input_ids, attention_mask, prediction_length, num_samples, temperature, top_k, top_p)
#     333 if top_p is None:
#     334     top_p = self.config.top_p
# --> 336 preds = self.model.generate(
#     337     input_ids=input_ids,
#     338     attention_mask=attention_mask,
#     339     generation_config=GenerationConfig(
#     340         min_new_tokens=prediction_length,
#     341         max_new_tokens=prediction_length,
#     342         do_sample=True,
#     343         num_return_sequences=num_samples,
#     344         eos_token_id=self.config.eos_token_id,
#     345         pad_token_id=self.config.pad_token_id,
#     346         temperature=temperature,
#     347         top_k=top_k,
#     348         top_p=top_p,
#     349     ),
#     350 )
#     352 if self.config.model_type == "seq2seq":
#     353     preds = preds[..., 1:]  # remove the decoder start token
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/transformers/generation/utils.py:2024, in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2015 logit_for_next_step = outputs.logits[:, -1, :]
#    2017 model_kwargs = self._update_model_kwargs_for_generation(
#    2018     outputs,
#    2019     model_kwargs,
#    2020     is_encoder_decoder=self.config.is_encoder_decoder,
#    2021     standardize_cache_format=True,
#    2022 )
#    2023 if not sequential:
# -> 2024     # Expands model inputs top_k times, for batched forward passes (akin to beam search).
#    2025     _, model_kwargs = self._expand_inputs_for_generation(
#    2026         expand_size=top_k, is_encoder_decoder=self.config.is_encoder_decoder, **model_kwargs
#    2027     )
#    2029 past_key_values = model_kwargs.get("past_key_values")
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/transformers/generation/utils.py:2982, in _sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2977 batch_beam_size, cur_len = input_ids.shape
#    2979 if num_beams * batch_size != batch_beam_size:
#    2980     raise ValueError(
#    2981         f"Batch dimension of `input_ids` should be {num_beams * batch_size}, but is {batch_beam_size}."
# -> 2982     )
#    2984 # init attention / hidden states / scores tuples
#    2985 scores = () if (return_dict_in_generate and output_scores) else None
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/transformers/models/t5/modeling_t5.py:1739, in forward(self, input_ids, attention_mask, decoder_input_ids, decoder_attention_mask, head_mask, decoder_head_mask, cross_attn_head_mask, encoder_outputs, past_key_values, inputs_embeds, decoder_inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1737 hidden_states = hidden_states.to(self.decoder.first_device)
#    1738 if decoder_input_ids is not None:
# -> 1739     decoder_input_ids = decoder_input_ids.to(self.decoder.first_device)
#    1740 if attention_mask is not None:
#    1741     attention_mask = attention_mask.to(self.decoder.first_device)
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/transformers/models/t5/modeling_t5.py:1106, in forward(self, input_ids, attention_mask, encoder_hidden_states, encoder_attention_mask, inputs_embeds, head_mask, cross_attn_head_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#    1105 def custom_forward(*inputs):
# -> 1106     return tuple(module(*inputs, use_cache, output_attentions))
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/transformers/models/t5/modeling_t5.py:686, in forward(self, hidden_states, attention_mask, position_bias, encoder_hidden_states, encoder_attention_mask, encoder_decoder_position_bias, layer_head_mask, cross_attn_layer_head_mask, past_key_value, use_cache, output_attentions, return_dict)
#     681 expected_num_past_key_values = 2 if encoder_hidden_states is None else 4
#     683 if len(past_key_value) != expected_num_past_key_values:
#     684     raise ValueError(
#     685         f"There should be {expected_num_past_key_values} past states. "
# --> 686         f"{'2 (past / key) for cross attention. ' if expected_num_past_key_values == 4 else ''}"
#     687         f"Got {len(past_key_value)} past key / value states"
#     688     )
#     690 self_attn_past_key_value = past_key_value[:2]
#     691 cross_attn_past_key_value = past_key_value[2:]
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/transformers/models/t5/modeling_t5.py:593, in forward(self, hidden_states, attention_mask, position_bias, layer_head_mask, past_key_value, use_cache, output_attentions)
#     588     self.layer_norm = T5LayerNorm(config.d_model, eps=config.layer_norm_epsilon)
#     589     self.dropout = nn.Dropout(config.dropout_rate)
#     591 def forward(
#     592     self,
# --> 593     hidden_states,
#     594     attention_mask=None,
#     595     position_bias=None,
#     596     layer_head_mask=None,
#     597     past_key_value=None,
#     598     use_cache=False,
#     599     output_attentions=False,
#     600 ):
#     601     normed_hidden_states = self.layer_norm(hidden_states)
#     602     attention_output = self.SelfAttention(
#     603         normed_hidden_states,
#     604         mask=attention_mask,
#    (...)
#     609         output_attentions=output_attentions,
#     610     )
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/transformers/models/t5/modeling_t5.py:515, in forward(self, hidden_states, mask, key_value_states, position_bias, past_key_value, layer_head_mask, query_length, use_cache, output_attentions)
#     509     elif past_key_value.shape[2] != key_value_states.shape[1]:
#     510         # checking that the `sequence_length` of the `past_key_value` is the same as
#     511         # the provided `key_value_states` to support prefix tuning
#     512         # cross-attn
#     513         # (batch_size, n_heads, seq_length, dim_per_head)
#     514         hidden_states = shape(proj_layer(key_value_states))
# --> 515     else:
#     516         # cross-attn
#     517         hidden_states = past_key_value
#     518 return hidden_states
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/transformers/models/t5/modeling_t5.py:499, in project(hidden_states, proj_layer, key_value_states, past_key_value)
#     495 if key_value_states is None:
#     496     # self-attn
#     497     # (batch_size, n_heads, seq_length, dim_per_head)
#     498     hidden_states = shape(proj_layer(hidden_states))
# --> 499 elif past_key_value is None:
#     500     # cross-attn
#     501     # (batch_size, n_heads, seq_length, dim_per_head)
#     502     hidden_states = shape(proj_layer(key_value_states))
#     504 if past_key_value is not None:
#
# KeyboardInterrupt:

# %%
print(chronos_forecast.shape)
# Out:
# torch.Size([3, 100, 64])

# %%
import matplotlib.pyplot as plt  # requires: pip install matplotlib
import numpy as np

low, median, high = np.quantile(chronos_forecast[:,:10,:].numpy(), [0.1, 0.5, 0.9], axis=1)
time_predict = np.linspace(end_time, end_time+predict_time, n_predict)
# Assuming event_counts_df is your DataFrame with a datetime index
# Get the last date from the event_counts_df index
print(median.shape)

fig,ax=plt.subplots(nrows=3,ncols=1)
for i in range(0,data.shape[0]):
    ax[i].plot(time,data[i,nstart:nend+n_predict],'r')
    ax[i].plot(time[:-n_predict],data[i,nstart:nend],'k')
    ax[i].plot(time_predict, median[i,:], 'g')
    ax[i].set_ylabel('Amplitude')
    ax[i].set_xlabel('Time (s)')
    ax[i].set_xlim([start_time,end_time+predict_time])
    ax[i].grid();
# Out:
# (3, 64)

# %% [markdown]
# ### MOIRAI

# %%
# Time series values. Shape: (batch, time, variate)
# add a dimension for the variate
# past_target = torch.tensor(np.expand_dims(data[:,nstart:nend], axis=0))

# past_target = rearrange(
#     torch.tensor(data[:,nstart:nend], dtype=torch.float32), "3 t -> 3 t 1" # 1 batch, t time, 1 variate
# )
past_target = rearrange(
    torch.tensor(data[0,nstart:nend], dtype=torch.float32), "t -> 1 t 1" # 1 batch, t time, 1 variate
)
# 1s if the value is observed, 0s otherwise. Shape: (batch, time, variate)
past_observed_target = torch.ones_like(past_target, dtype=torch.bool)
# 1s if the value is padding, 0s otherwise. Shape: (batch, time)
past_is_pad = torch.zeros_like(past_target, dtype=torch.bool).squeeze(-1)

# %%
print("Shape of past_target:", past_target.shape)
print("Shape of past_observed_target:", past_observed_target.shape)
print("Shape of past_is_pad:", past_is_pad.shape)
# Out:
# Shape of past_target: torch.Size([1, 100, 1])
# Shape of past_observed_target: torch.Size([1, 100, 1])
# Shape of past_is_pad: torch.Size([1, 100])

# %%
moirai_forecast = moirai_model(
    past_target=past_target,
    past_observed_target=past_observed_target,
    past_is_pad=past_is_pad)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 moirai_forecast = moirai_model(
#       2     past_target=past_target,
#       3     past_observed_target=past_observed_target,
#       4     past_is_pad=past_is_pad)
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/GitHub/quakeLLM/src/uni2ts/src/uni2ts/model/moirai/forecast.py:260, in MoiraiForecast.forward(self, past_target, past_observed_target, past_is_pad, feat_dynamic_real, observed_feat_dynamic_real, past_feat_dynamic_real, past_observed_feat_dynamic_real, num_samples)
#     257 preds = []
#     258 for patch_size in self.module.patch_sizes:
#     259     val_loss.append(
# --> 260         self._val_loss(
#     261             patch_size=patch_size,
#     262             target=past_target[..., : self.past_length, :],
#     263             observed_target=past_observed_target[
#     264                 ..., : self.past_length, :
#     265             ],
#     266             is_pad=past_is_pad[..., : self.past_length],
#     267             feat_dynamic_real=(
#     268                 feat_dynamic_real[..., : self.past_length, :]
#     269                 if feat_dynamic_real is not None
#     270                 else None
#     271             ),
#     272             observed_feat_dynamic_real=(
#     273                 observed_feat_dynamic_real[..., : self.past_length, :]
#     274                 if observed_feat_dynamic_real is not None
#     275                 else None
#     276             ),
#     277             past_feat_dynamic_real=(
#     278                 past_feat_dynamic_real[
#     279                     ..., : self.hparams.context_length, :
#     280                 ]
#     281                 if past_feat_dynamic_real is not None
#     282                 else None
#     283             ),
#     284             past_observed_feat_dynamic_real=(
#     285                 past_observed_feat_dynamic_real[
#     286                     ..., : self.hparams.context_length, :
#     287                 ]
#     288                 if past_observed_feat_dynamic_real is not None
#     289                 else None
#     290             ),
#     291         )
#     292     )
#     293     distr = self._get_distr(
#     294         patch_size,
#     295         past_target[..., -self.hparams.context_length :, :],
#    (...)
#     319         ),
#     320     )
#     321     preds.append(
#     322         self._format_preds(
#     323             patch_size,
#    (...)
#     328         )
#     329     )
#
# File ~/GitHub/quakeLLM/src/uni2ts/src/uni2ts/model/moirai/forecast.py:391, in MoiraiForecast._val_loss(self, patch_size, target, observed_target, is_pad, feat_dynamic_real, observed_feat_dynamic_real, past_feat_dynamic_real, past_observed_feat_dynamic_real)
#     368 (
#     369     target,
#     370     observed_mask,
#    (...)
#     388     past_observed_feat_dynamic_real=past_observed_feat_dynamic_real,
#     389 )
#     390 # get predictions
# --> 391 distr = self.module(
#     392     target,
#     393     observed_mask,
#     394     sample_id,
#     395     time_id,
#     396     variate_id,
#     397     prediction_mask,
#     398     torch.ones_like(time_id, dtype=torch.long) * patch_size,
#     399 )
#     400 val_loss = self.per_sample_loss_func(
#     401     pred=distr,
#     402     target=target,
#    (...)
#     406     variate_id=variate_id,
#     407 )
#     408 return val_loss
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/opt/miniconda3/envs/quakellm/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/GitHub/quakeLLM/src/uni2ts/src/uni2ts/model/moirai/module.py:163, in MoiraiModule.forward(self, target, observed_mask, sample_id, time_id, variate_id, prediction_mask, patch_size)
#     131 def forward(
#     132     self,
#     133     target: Float[torch.Tensor, "*batch seq_len max_patch"],
#    (...)
#     139     patch_size: Int[torch.Tensor, "*batch seq_len"],
#     140 ) -> Distribution:
#     141     """
#     142     Defines the forward pass of MoiraiModule.
#     143     This method expects processed inputs.
#    (...)
#     159     :return: predictive distribution
#     160     """
#     161     loc, scale = self.scaler(
#     162         target,
# --> 163         observed_mask * ~prediction_mask.unsqueeze(-1),
#     164         sample_id,
#     165         variate_id,
#     166     )
#     167     scaled_target = (target - loc) / scale
#     168     reprs = self.in_proj(scaled_target, patch_size)
#
# RuntimeError: The size of tensor a (13) must match the size of tensor b (54) at non-singleton dimension 1

# %% [markdown]
# ### MOMENT

# %%
from pprint import pprint
import torch

# takes in tensor of shape [batchsize, n_channels, context_length]
x = torch.randn(16, 1, 512)
output = model(x)
pprint(output)
